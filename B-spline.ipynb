# %%
# %matplotlib inline
import pandas as pd
import os,sys
import numpy as np
import math 
import matplotlib.pyplot as plt

# %%
x_d = np.array([1.5, 2, 2.5, 3, 3.5])
y_d = np.array([2.5, 3, 2.5, 2, 3])

x = np.empty(0)
y = np.empty(0)

fl = open(r"C:\Users\alexk\JupyterWorks\test.txt", "r") 
for line in fl:
    tmp = line.split(" ")
    x = np.concatenate( ( x, [float(tmp[0])] ) , axis=0)
    y = np.concatenate( ( y, [float(tmp[1])] ) , axis=0)

fl.close()

# %%
print(x)
# Out:
# [1.5    1.5005 1.501  ... 3.499  3.4995 3.5   ]

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
#ax.set(xlim=(0.05,0.2), ylim=(0.01, 0.02))
linestyles = ['-', '--', '-.']
grlinecolors = ['#000000', '#555555', '#aaaaaa']
linecolors = ['#000000', '#3163e1', '#ff9b2f']

ax.plot(x, y, lw=1.5, color='k')
ax.plot(x_d, y_d, lw=2, color='r')


#ax.axis('equal')
plt.grid(True,linewidth=0.5)
plt.tight_layout()
plt.show()
